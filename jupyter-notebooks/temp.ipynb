# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeyShchus/Satellite-Imagery-Analysis-with-Python/blob/master/jupyter-notebooks/temp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the os module in order to access environment variables
import os

# If you're following along with this notebook, you can enter your API Key on the following line, and uncomment it:
#os.environ['PL_API_KEY']='YOUR API KEY HERE'

# Setup the API Key from the `PL_API_KEY` environment variable
PLANET_API_KEY = os.getenv('307f0e5e53624aa2b600d67ed6ca088b')

# %%
# Import helper modules
import json
import requests

# %%
# Helper function to printformatted JSON using the json module
def p(data):
    print(json.dumps(data, indent=2))

# %%
# Setup Planet Data API base URL
URL = "https://api.planet.com/data/v1"

# Setup the session
session = requests.Session()

# Authenticate
session.auth = ('307f0e5e53624aa2b600d67ed6ca088b', '')

# %%
# Make a GET request to the Planet Data API
res = session.get(URL)

# %%
# Response status code
res.status_code
# Out:
# 200

# %%
# Response Body
res.text
# Out:
# '{"_links": {"_self": "https://api.planet.com/data/v1/", "asset-types": "https://api.planet.com/data/v1/asset-types/", "item-types": "https://api.planet.com/data/v1/item-types/", "spec": "https://api.planet.com/data/v1/spec"}}'

# %%
# Print formatted JSON response
p(res.json())
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/",
#     "asset-types": "https://api.planet.com/data/v1/asset-types/",
#     "item-types": "https://api.planet.com/data/v1/item-types/",
#     "spec": "https://api.planet.com/data/v1/spec"
#   }
# }

# %%
# Print the value of the item-types key from _links
print(res.json()["_links"]["item-types"])
# Out:
# https://api.planet.com/data/v1/item-types/

# %%
# Setup the stats URL
stats_url = "{}/stats".format(URL)

# Print the stats URL
print(stats_url)
# Out:
# https://api.planet.com/data/v1/stats

# %%
# Specify the sensors/satellites or "item types" to include in our results
item_types = ["PSScene3Band", "REOrthoTile"]

# %%
# Create filter object for all imagery captured between 2013-01-01 and present.
date_filter = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "gte": "2013-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

# %%
# Construct the request.
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "interval": "year",
#   "utc_offset": "+0h",
#   "buckets": [
#     {
#       "count": 3112975,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3596153,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8492329,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 39665025,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 210843156,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 287882121,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 228967997,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 71588930,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %%
# Fill in this filter to complete the exercise! 
date_filter2 = {
}

request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

res = session.post(stats_url, json=request)
p(res.json())
# Out:
# {
#   "interval": "year",
#   "utc_offset": "+0h",
#   "buckets": [
#     {
#       "count": 3112975,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3596153,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8492329,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 39665025,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 210843156,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 287882121,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 228967997,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 71588930,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %%
# Search for imagery only from PlanetScope satellites that have a PS2 telescope

# Setup item types
item_types = ["PSScene3Band"]

# Setup a filter for instrument type
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "interval": "year",
#   "utc_offset": "+0h",
#   "buckets": [
#     {
#       "count": 1540419,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 32228791,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 206745630,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 284909476,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 212868897,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 64223733,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %%
# Fill in this filter to complete the exercise! 

instrument_filter2 = {
}
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : instrument_filter2
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "field": {
#     "filter.type": [
#       {
#         "message": "'type' is a required property"
#       }
#     ]
#   },
#   "general": []
# }

# %%
# Search for imagery that only intersects with 40N, 90W

# Setup GeoJSON 
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup Geometry Filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": "POINT(-90 40)"
}

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "field": {
#     "filter.config": [
#       {
#         "message": "'POINT(-90 40)' is not of type 'object'"
#       }
#     ],
#     "interval": [
#       {
#         "message": "'interval' is a required property"
#       }
#     ]
#   },
#   "general": []
# }

# %%
# PS2 imagery; over 40N, 90W; captured between 2013 and present

# Setup an "AND" logical filter
and_filter = {
    "type": "AndFilter",
    "config": [instrument_filter, geometry_filter, date_filter]
}

# Print the logical filter
p(and_filter)
# Out:
# {
#   "type": "AndFilter",
#   "config": [
#     {
#       "type": "StringInFilter",
#       "field_name": "instrument",
#       "config": [
#         "PS2"
#       ]
#     },
#     {
#       "type": "GeometryFilter",
#       "field_name": "geometry",
#       "config": "POINT(-90 40)"
#     },
#     {
#       "type": "DateRangeFilter",
#       "field_name": "acquired",
#       "config": {
#         "gte": "2013-01-01T00:00:00.000Z"
#       }
#     }
#   ]
# }

# %%
# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : and_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "field": {
#     "filter.config.1.config": [
#       {
#         "message": "'POINT(-90 40)' is not of type 'object'"
#       }
#     ]
#   },
#   "general": []
# }

# %%
# Setup Item Types
item_types = ["PSScene4Band"]

# Setup Instrument Filter
instrument_filter = {
    "type": "StringInFilter",
    "field_name": "instrument",
    "config": ["PS2"]
}

# Setup "not" Logical Filter
not_filter = {
    "type": "NotFilter",
    "config": instrument_filter
}

# Setup the request
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : not_filter
}

# Send the POST request to the API stats endpoint
res=session.post(stats_url, json=request)

# Print response
p(res.json())
# Out:
# {
#   "interval": "year",
#   "utc_offset": "+0h",
#   "buckets": [
#     {
#       "count": 13343596,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 6691838,
#       "start_time": "2020-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %%
# Setup the quick search endpoint url
quick_url = "{}/quick-search".format(URL)

# %%
# Setup Item Types
item_types = ["PSScene4Band"]

# Setup GeoJSON for only imagery that intersects with 40N, 90W
geom = {
    "type": "Point",
    "coordinates": [
        -90,
         40
    ]
}

# Setup a geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": "POINT(40 -90)"
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "field": {
#     "filter.config": [
#       {
#         "message": "'POINT(40 -90)' is not of type 'object'"
#       }
#     ]
#   },
#   "general": []
# }

# %%
# Setup Item Types
item_types = ["PSScene3Band"]

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : not_filter
}

# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# Print the response
p(geojson)
# Out:
# {
#   "_links": {
#     "_first": "https://api.planet.com/data/v1/searches/8551230d5981477ab517a8de3ba4fd66/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#     "_next": "https://api.planet.com/data/v1/searches/8551230d5981477ab517a8de3ba4fd66/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIwLTA1LTA1VDIwOjEwOjUwLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjAwNTA1XzA4MTgxM184Nl8yMjU3IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#     "_self": "https://api.planet.com/data/v1/searches/8551230d5981477ab517a8de3ba4fd66/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
#   },
#   "features": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080450_13_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080450_13_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080450_13_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               28.19451222690982,
#               37.30949385567106
#             ],
#             [
#               28.145110104729046,
#               37.127195256210435
#             ],
#             [
#               28.525980203255905,
#               37.06018626656168
#             ],
#             [
#               28.576137447081344,
#               37.2424386547623
#             ],
#             [
#               28.19451222690982,
#               37.30949385567106
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_080450_13_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:04:50.135195Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 12693,
#         "epsg_code": 32635,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 601719,
#         "origin_y": 4129878,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:19:39Z",
#         "quality_category": "test",
#         "rows": 9080,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 120.4,
#         "sun_elevation": 56.7,
#         "updated": "2020-05-05T20:19:39Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080456_81_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080456_81_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080456_81_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               28.0801912095841,
#               36.89022906247991
#             ],
#             [
#               28.03098131530732,
#               36.707727100686974
#             ],
#             [
#               28.41043006843276,
#               36.640983646753405
#             ],
#             [
#               28.460308361389053,
#               36.823483540683476
#             ],
#             [
#               28.0801912095841,
#               36.89022906247991
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_080456_81_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:04:56.814395Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12718,
#         "epsg_code": 32635,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 592083,
#         "origin_y": 4083240,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:19:05Z",
#         "quality_category": "test",
#         "rows": 9089,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 119.8,
#         "sun_elevation": 56.8,
#         "updated": "2020-05-05T20:19:05Z",
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081535_79_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081535_79_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081535_79_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               19.38090611250679,
#               -3.3440575056683386
#             ],
#             [
#               19.34431830073082,
#               -3.529774321246807
#             ],
#             [
#               19.652721739841827,
#               -3.590621159722135
#             ],
#             [
#               19.6889542716201,
#               -3.4056722108166824
#             ],
#             [
#               19.38090611250679,
#               -3.3440575056683386
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081535_79_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:15:35.791195Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.07,
#         "columns": 12758,
#         "epsg_code": 32734,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 316083,
#         "origin_y": 9630231,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:17:13Z",
#         "quality_category": "test",
#         "rows": 9073,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 59.6,
#         "sun_elevation": 49.5,
#         "updated": "2020-05-05T20:17:13Z",
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080857_26_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080857_26_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080857_26_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               24.466590289730306,
#               21.783185073519935
#             ],
#             [
#               24.426648762201438,
#               21.59970855868124
#             ],
#             [
#               24.754925254094715,
#               21.537084601081347
#             ],
#             [
#               24.795080125672655,
#               21.72042912025517
#             ],
#             [
#               24.466590289730306,
#               21.783185073519935
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_080857_26_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:08:57.265595Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12784,
#         "epsg_code": 32635,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 233571,
#         "origin_y": 2410980,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:17:04Z",
#         "quality_category": "test",
#         "rows": 9239,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 94,
#         "sun_elevation": 59.1,
#         "updated": "2020-05-05T20:17:04Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_074053_56_2278",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_074053_56_2278/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_074053_56_2278/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               23.500383159484468,
#               -33.83364565383883
#             ],
#             [
#               23.45116957771383,
#               -34.02236435003445
#             ],
#             [
#               23.831075528561108,
#               -34.09061294620796
#             ],
#             [
#               23.879109064613573,
#               -33.90149670815437
#             ],
#             [
#               23.500383159484468,
#               -33.83364565383883
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_074053_56_2278",
#       "properties": {
#         "acquired": "2020-05-05T07:40:53.566709Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 13302,
#         "epsg_code": 32734,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 726324,
#         "origin_y": 6253479,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:13:30Z",
#         "quality_category": "test",
#         "rows": 9767,
#         "satellite_id": "2278",
#         "strip_id": "3371941",
#         "sun_azimuth": 44,
#         "sun_elevation": 26.7,
#         "updated": "2020-05-05T20:13:30Z",
#         "view_angle": 0.2
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082036_35_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082036_35_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082036_35_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               15.48252087430965,
#               -22.24776872054122
#             ],
#             [
#               15.44097752016985,
#               -22.43524226076685
#             ],
#             [
#               15.778794867228463,
#               -22.499524914081867
#             ],
#             [
#               15.819727344218931,
#               -22.31191800620734
#             ],
#             [
#               15.48252087430965,
#               -22.24776872054122
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_082036_35_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:20:36.355195Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 13018,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 545376,
#         "origin_y": 7539669,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:47Z",
#         "quality_category": "test",
#         "rows": 9333,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 47.4,
#         "sun_elevation": 36,
#         "updated": "2020-05-05T20:11:47Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081611_41_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081611_41_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081611_41_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               18.93703339308663,
#               -5.589468106861229
#             ],
#             [
#               18.90008823717164,
#               -5.775078351219067
#             ],
#             [
#               19.2107533318706,
#               -5.837383983332641
#             ],
#             [
#               19.24734717439367,
#               -5.651762004528519
#             ],
#             [
#               18.93703339308663,
#               -5.589468106861229
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081611_41_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:16:11.413595Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.09,
#         "columns": 12809,
#         "epsg_code": 32734,
#         "ground_control": false,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 267459,
#         "origin_y": 9381777,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:45Z",
#         "quality_category": "test",
#         "rows": 9107,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 57.6,
#         "sun_elevation": 48,
#         "updated": "2020-05-05T20:11:45Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082114_20_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082114_20_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082114_20_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               14.9517511347203,
#               -24.621321273569293
#             ],
#             [
#               14.908940526264093,
#               -24.809325130247178
#             ],
#             [
#               15.253772351078869,
#               -24.874169264063394
#             ],
#             [
#               15.295810798072619,
#               -24.68620841779153
#             ],
#             [
#               14.9517511347203,
#               -24.621321273569293
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_082114_20_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:21:14.203995Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 13043,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 490797,
#         "origin_y": 7276983,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:41Z",
#         "quality_category": "test",
#         "rows": 9341,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 46.5,
#         "sun_elevation": 34.1,
#         "updated": "2020-05-05T20:11:41Z",
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081121_98_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081121_98_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081121_98_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               22.558591127034333,
#               12.663557126789623
#             ],
#             [
#               22.521064300855112,
#               12.47949603192218
#             ],
#             [
#               22.8346249086108,
#               12.417746747947024
#             ],
#             [
#               22.87215546537723,
#               12.601757908436323
#             ],
#             [
#               22.558591127034333,
#               12.663557126789623
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081121_98_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:11:21.981595Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12691,
#         "epsg_code": 32634,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 665298,
#         "origin_y": 1400436,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:39Z",
#         "quality_category": "test",
#         "rows": 9001,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 79,
#         "sun_elevation": 57.2,
#         "updated": "2020-05-05T20:11:39Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082100_84_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082100_84_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082100_84_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               15.140385794220396,
#               -23.78461119383096
#             ],
#             [
#               15.09803591685959,
#               -23.972477844711086
#             ],
#             [
#               15.440327210875544,
#               -24.037179889154963
#             ],
#             [
#               15.481991739925745,
#               -23.849331303023217
#             ],
#             [
#               15.140385794220396,
#               -23.78461119383096
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_082100_84_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:21:00.845595Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 13037,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 509973,
#         "origin_y": 7369614,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:36Z",
#         "quality_category": "test",
#         "rows": 9343,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 46.8,
#         "sun_elevation": 34.8,
#         "updated": "2020-05-05T20:11:36Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082007_41_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082007_41_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082007_41_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               15.880215154025482,
#               -20.434598687863293
#             ],
#             [
#               15.839571058289021,
#               -20.621820229698546
#             ],
#             [
#               16.172622697048805,
#               -20.685521355329122
#             ],
#             [
#               16.21276641657992,
#               -20.498269289108862
#             ],
#             [
#               15.880215154025482,
#               -20.434598687863293
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_082007_41_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:20:07.411995Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12997,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 587475,
#         "origin_y": 7740180,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:35Z",
#         "quality_category": "test",
#         "rows": 9322,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 48.2,
#         "sun_elevation": 37.4,
#         "updated": "2020-05-05T20:11:35Z",
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081913_97_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081913_97_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081913_97_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               16.59689706104067,
#               -17.07695760705767
#             ],
#             [
#               16.55744533292925,
#               -17.263874016793604
#             ],
#             [
#               16.883160540837558,
#               -17.32700659679766
#             ],
#             [
#               16.922174090326756,
#               -17.140085774758443
#             ],
#             [
#               16.59689706104067,
#               -17.07695760705767
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081913_97_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:19:13.978395Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12974,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 665562,
#         "origin_y": 8111238,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:35Z",
#         "quality_category": "test",
#         "rows": 9317,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 49.8,
#         "sun_elevation": 40,
#         "updated": "2020-05-05T20:11:35Z",
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081829_45_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081829_45_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081829_45_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               17.180764952298514,
#               -14.277643773940776
#             ],
#             [
#               17.14214785004093,
#               -14.464115328560036
#             ],
#             [
#               17.462556201329882,
#               -14.526769478858066
#             ],
#             [
#               17.500791803200965,
#               -14.340263250285929
#             ],
#             [
#               17.180764952298514,
#               -14.277643773940776
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081829_45_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:18:29.450395Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12944,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 730905,
#         "origin_y": 8420463,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:35Z",
#         "quality_category": "test",
#         "rows": 9294,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 51.4,
#         "sun_elevation": 42,
#         "updated": "2020-05-05T20:11:35Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082118_65_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082118_65_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_082118_65_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               14.888009887533174,
#               -24.900402561411536
#             ],
#             [
#               14.845009861110325,
#               -25.088540008940182
#             ],
#             [
#               15.190704546474448,
#               -25.15361175817758
#             ],
#             [
#               15.23291188232059,
#               -24.9655525023119
#             ],
#             [
#               14.888009887533174,
#               -24.900402561411536
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_082118_65_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:21:18.656795Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 13047,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 484371,
#         "origin_y": 7246077,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:34Z",
#         "quality_category": "test",
#         "rows": 9350,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 46.4,
#         "sun_elevation": 33.9,
#         "updated": "2020-05-05T20:11:34Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081802_73_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081802_73_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081802_73_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               17.526332789446748,
#               -12.597226026802305
#             ],
#             [
#               17.488218396573462,
#               -12.783556403876545
#             ],
#             [
#               17.80600146038171,
#               -12.845950325938716
#             ],
#             [
#               17.84382681952104,
#               -12.659657645375534
#             ],
#             [
#               17.526332789446748,
#               -12.597226026802305
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081802_73_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:18:02.733595Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12929,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 770133,
#         "origin_y": 8606085,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:33Z",
#         "quality_category": "test",
#         "rows": 9282,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 52.4,
#         "sun_elevation": 43.2,
#         "updated": "2020-05-05T20:11:33Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081549_14_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081549_14_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081549_14_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               19.215104982977493,
#               -4.1847131175043435
#             ],
#             [
#               19.17866038769717,
#               -4.372129221582596
#             ],
#             [
#               19.48910782599129,
#               -4.432312749246896
#             ],
#             [
#               19.522745367647676,
#               -4.244504043275888
#             ],
#             [
#               19.215104982977493,
#               -4.1847131175043435
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081549_14_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:15:49.149595Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.1,
#         "columns": 12723,
#         "epsg_code": 32734,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 297882,
#         "origin_y": 9537231,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:33Z",
#         "quality_category": "test",
#         "rows": 9106,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 58.8,
#         "sun_elevation": 48.9,
#         "updated": "2020-05-05T20:11:33Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081842_80_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081842_80_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081842_80_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               17.00653107227617,
#               -15.11815614326381
#             ],
#             [
#               16.967757649448426,
#               -15.30467437239674
#             ],
#             [
#               17.28965892217991,
#               -15.367517549070918
#             ],
#             [
#               17.328086962440693,
#               -15.180906631579292
#             ],
#             [
#               17.00653107227617,
#               -15.11815614326381
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081842_80_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:18:42.808795Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12951,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 711282,
#         "origin_y": 8327622,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:32Z",
#         "quality_category": "test",
#         "rows": 9300,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 50.9,
#         "sun_elevation": 41.4,
#         "updated": "2020-05-05T20:11:32Z",
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081053_03_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081053_03_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081053_03_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               22.931379273968485,
#               14.487781046862827
#             ],
#             [
#               22.893503119384256,
#               14.303879323501533
#             ],
#             [
#               23.20907642197287,
#               14.242068681048325
#             ],
#             [
#               23.247058553037842,
#               14.425856158348061
#             ],
#             [
#               22.931379273968485,
#               14.487781046862827
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081053_03_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:10:53.038395Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12674,
#         "epsg_code": 32634,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 704241,
#         "origin_y": 1602552,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:31Z",
#         "quality_category": "test",
#         "rows": 8975,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 81.9,
#         "sun_elevation": 57.8,
#         "updated": "2020-05-05T20:11:31Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081818_31_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081818_31_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081818_31_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               17.324956819846932,
#               -13.576875702887541
#             ],
#             [
#               17.286569571724428,
#               -13.763162774775742
#             ],
#             [
#               17.60584938214482,
#               -13.825717919933068
#             ],
#             [
#               17.643965164085998,
#               -13.639291415532789
#             ],
#             [
#               17.324956819846932,
#               -13.576875702887541
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081818_31_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:18:18.318395Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12940,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 747237,
#         "origin_y": 8497872,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:11:30Z",
#         "quality_category": "test",
#         "rows": 9286,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 51.8,
#         "sun_elevation": 42.5,
#         "updated": "2020-05-05T20:11:30Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081213_18_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081213_18_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081213_18_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               21.907224785389673,
#               9.431900185596742
#             ],
#             [
#               21.87018243742242,
#               9.247450412561347
#             ],
#             [
#               22.18091458998002,
#               9.186014075891045
#             ],
#             [
#               22.21795383254023,
#               9.37038234226018
#             ],
#             [
#               21.907224785389673,
#               9.431900185596742
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081213_18_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:12:13.188795Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 12720,
#         "epsg_code": 32634,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 595581,
#         "origin_y": 1042734,
#         "pixel_resolution": 3,
# ...
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               20.01770480982571,
#               -0.11431873941241208
#             ],
#             [
#               19.981263810068825,
#               -0.29972210036982033
#             ],
#             [
#               20.289353399453073,
#               -0.36119484474646896
#             ],
#             [
#               20.32582355066978,
#               -0.1758291201726437
#             ],
#             [
#               20.01770480982571,
#               -0.11431873941241208
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081444_58_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:14:44.583995Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12782,
#         "epsg_code": 32734,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 386634,
#         "origin_y": 9987363,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:10:51Z",
#         "quality_category": "test",
#         "rows": 9097,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 62.7,
#         "sun_elevation": 51.4,
#         "updated": "2020-05-05T20:10:51Z",
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081017_41_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081017_41_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081017_41_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               23.3944944609629,
#               16.73217152438464
#             ],
#             [
#               23.356183816904643,
#               16.548535673185757
#             ],
#             [
#               23.675054351729518,
#               16.48647616336054
#             ],
#             [
#               23.71346976748628,
#               16.670228177109664
#             ],
#             [
#               23.3944944609629,
#               16.73217152438464
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081017_41_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:10:17.415995Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12657,
#         "epsg_code": 32634,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 751452,
#         "origin_y": 1851465,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:10:51Z",
#         "quality_category": "test",
#         "rows": 8942,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 85.5,
#         "sun_elevation": 58.3,
#         "updated": "2020-05-05T20:10:51Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080906_17_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080906_17_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080906_17_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               24.345427724056254,
#               21.221617544446495
#             ],
#             [
#               24.305991710566325,
#               21.038609513099427
#             ],
#             [
#               24.633328432347607,
#               20.97613407478837
#             ],
#             [
#               24.67263156955576,
#               21.159358824915678
#             ],
#             [
#               24.345427724056254,
#               21.221617544446495
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_080906_17_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:09:06.171195Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12774,
#         "epsg_code": 32635,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 220008,
#         "origin_y": 2348988,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:10:51Z",
#         "quality_category": "test",
#         "rows": 9221,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 93.1,
#         "sun_elevation": 59,
#         "updated": "2020-05-05T20:10:51Z",
#         "view_angle": 0
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080852_81_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080852_81_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080852_81_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               24.526896141046674,
#               22.063456246434086
#             ],
#             [
#               24.4869394005406,
#               21.879844517890888
#             ],
#             [
#               24.81590665998999,
#               21.817178416823133
#             ],
#             [
#               24.856048971073122,
#               22.00044002653911
#             ],
#             [
#               24.526896141046674,
#               22.063456246434086
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_080852_81_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:08:52.812795Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12781,
#         "epsg_code": 32635,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 240321,
#         "origin_y": 2441922,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:10:51Z",
#         "quality_category": "test",
#         "rows": 9244,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 94.5,
#         "sun_elevation": 59.1,
#         "updated": "2020-05-05T20:10:51Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080507_94_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080507_94_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_080507_94_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               27.894313641337597,
#               36.192791487914484
#             ],
#             [
#               27.845895945508392,
#               36.01030100909124
#             ],
#             [
#               28.22196727245885,
#               35.94399833196086
#             ],
#             [
#               28.271135251475183,
#               36.12660743665876
#             ],
#             [
#               27.894313641337597,
#               36.192791487914484
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_080507_94_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:05:07.946395Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12719,
#         "epsg_code": 32635,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 576228,
#         "origin_y": 4005705,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:10:51Z",
#         "quality_category": "test",
#         "rows": 9093,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 118.7,
#         "sun_elevation": 57.1,
#         "updated": "2020-05-05T20:10:51Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_040549_47_2277",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_040549_47_2277/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_040549_47_2277/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               90.59144847946665,
#               47.87356730055242
#             ],
#             [
#               90.52728958000297,
#               47.69256002374964
#             ],
#             [
#               90.97488375764297,
#               47.61885699040644
#             ],
#             [
#               91.04098274024938,
#               47.799387054479745
#             ],
#             [
#               90.59144847946665,
#               47.87356730055242
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_040549_47_2277",
#       "properties": {
#         "acquired": "2020-05-05T04:05:49.472474Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0.01,
#         "columns": 12949,
#         "epsg_code": 32646,
#         "ground_control": true,
#         "gsd": 3.9,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 314457,
#         "origin_y": 5305059,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:10:51Z",
#         "quality_category": "test",
#         "rows": 9711,
#         "satellite_id": "2277",
#         "strip_id": "3371933",
#         "sun_azimuth": 135.6,
#         "sun_elevation": 51.6,
#         "updated": "2020-05-05T20:10:51Z",
#         "view_angle": 0.1
#       },
#       "type": "Feature"
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081813_86_2257",
#         "assets": "https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081813_86_2257/assets/",
#         "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene3Band/items/20200505_081813_86_2257/thumb"
#       },
#       "_permissions": [
#         "assets.analytic:download",
#         "assets.analytic_dn:download",
#         "assets.analytic_xml:download",
#         "assets.analytic_dn_xml:download",
#         "assets.basic_analytic:download",
#         "assets.basic_analytic_dn:download",
#         "assets.basic_analytic_dn_xml:download",
#         "assets.basic_analytic_dn_rpc:download",
#         "assets.basic_analytic_xml:download",
#         "assets.basic_analytic_rpc:download",
#         "assets.basic_udm:download",
#         "assets.udm:download",
#         "assets.visual:download",
#         "assets.visual_xml:download"
#       ],
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               17.382706786750656,
#               -13.296058543974736
#             ],
#             [
#               17.344220542317785,
#               -13.482498797357092
#             ],
#             [
#               17.6631839340185,
#               -13.54495828833517
#             ],
#             [
#               17.701078728650547,
#               -13.358664092664064
#             ],
#             [
#               17.382706786750656,
#               -13.296058543974736
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "id": "20200505_081813_86_2257",
#       "properties": {
#         "acquired": "2020-05-05T08:18:13.865595Z",
#         "anomalous_pixels": 0,
#         "cloud_cover": 0,
#         "columns": 12937,
#         "epsg_code": 32733,
#         "ground_control": true,
#         "gsd": 4,
#         "instrument": "PSB.SD",
#         "item_type": "PSScene3Band",
#         "origin_x": 753771,
#         "origin_y": 8528889,
#         "pixel_resolution": 3,
#         "provider": "planetscope",
#         "published": "2020-05-05T20:10:50Z",
#         "quality_category": "test",
#         "rows": 9287,
#         "satellite_id": "2257",
#         "strip_id": "3372039",
#         "sun_azimuth": 52,
#         "sun_elevation": 42.7,
#         "updated": "2020-05-05T20:10:50Z",
#         "view_angle": 0.2
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %%
# Setup a GeoJSON polygon for our geometry filter
geom = {
    "type": "Polygon",
    "coordinates": [
      [
        [
          -125.29632568359376,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          49.335861591104106
        ],
        [
          -123.2391357421875,
          48.37084770238366
        ],
        [
          -125.29632568359376,
          48.37084770238366
        ]
      ]
    ]
  }

# Setup the geometry filter
geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": geom
}

# Setup the request
request = {
    "item_types" : item_types,
    "filter" : geometry_filter
}

# %%
# Send the POST request to the API quick search endpoint
res = session.post(quick_url, json=request)

# Assign the response to a variable
geojson = res.json()

# %%
# Print the response "_links" property
p(geojson["_links"])
# Out:
# {
#   "_first": "https://api.planet.com/data/v1/searches/17dd36528f4e4386b3775f20a72a205e/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/17dd36528f4e4386b3775f20a72a205e/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIwLTA1LTAxVDIyOjQwOjAxLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjAwNTAxXzE4NTEyMF8xMDE0IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319",
#   "_self": "https://api.planet.com/data/v1/searches/17dd36528f4e4386b3775f20a72a205e/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9wcmV2IjogZmFsc2UsICJxdWVyeV9wYXJhbXMiOiB7fX0%3D"
# }

# %%
# Assign the "_links" -> "_next" property (link to next page of results) to a variable 
next_url = geojson["_links"]["_next"]

# Print the link to the next page of results
print(next_url)
# Out:
# https://api.planet.com/data/v1/searches/17dd36528f4e4386b3775f20a72a205e/results?_page=eyJwYWdlX3NpemUiOiAyNTAsICJzb3J0X2J5IjogInB1Ymxpc2hlZCIsICJzb3J0X2Rlc2MiOiB0cnVlLCAic29ydF9zdGFydCI6ICIyMDIwLTA1LTAxVDIyOjQwOjAxLjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMjAwNTAxXzE4NTEyMF8xMDE0IiwgInNvcnRfcHJldiI6IGZhbHNlLCAicXVlcnlfcGFyYW1zIjoge319

# %%
# Send the POST request to the API quick search endpoint with a page size of 9
res = session.post(quick_url, json=request, params={"_page_size" : 9})

# Assign the response to a variable
geojson = res.json()

# Get the number of features present in the response
len(geojson["features"])
# Out:
# 9

# %%
# !pip install geojsonio
# Out:
# Collecting geojsonio
#   Downloading https://files.pythonhosted.org/packages/7f/42/a773a4d4a6a78261dce418269cd017d8ff401206bc5724d9390084ebbf3d/geojsonio-0.0.3.tar.gz
# Collecting github3.py
#   Downloading https://files.pythonhosted.org/packages/a6/21/9055a739fbe7b22a8e99e42906f2c75ba02bab9fd193a85837cd1d6e55d3/github3.py-1.3.0-py2.py3-none-any.whl (153kB)
#      |████████████████████████████████| 153kB 4.8MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from geojsonio) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from github3.py->geojsonio) (2.8.1)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from github3.py->geojsonio) (3.0.1)
# Requirement already satisfied: requests>=2.18 in /usr/local/lib/python3.6/dist-packages (from github3.py->geojsonio) (2.23.0)
# Collecting jwcrypto>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/ad/dd/3a637bd1ee446bde1984325321cb606c44accfe5f095352d65166c080e14/jwcrypto-0.7-py2.py3-none-any.whl (78kB)
#      |████████████████████████████████| 81kB 10.4MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->github3.py->geojsonio) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->github3.py->geojsonio) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->github3.py->geojsonio) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.18->github3.py->geojsonio) (2.9)
# Collecting cryptography>=1.5
#   Downloading https://files.pythonhosted.org/packages/3c/04/686efee2dcdd25aecf357992e7d9362f443eb182ecd623f882bc9f7a6bba/cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 49.3MB/s
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=1.5->jwcrypto>=0.5.0->github3.py->geojsonio) (1.14.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.5->jwcrypto>=0.5.0->github3.py->geojsonio) (2.20)
# Building wheels for collected packages: geojsonio
#   Building wheel for geojsonio (setup.py) ... done
#   Created wheel for geojsonio: filename=geojsonio-0.0.3-cp36-none-any.whl size=5036 sha256=82b6c2dfe559ff487e6b6b3909640e02fa0783519fc4c41f72a064f1a94bdf43
#   Stored in directory: /root/.cache/pip/wheels/a9/ef/7c/7bbf228825e8717adaa84cd4b6c4ed8649b7958dd2bac45076
# Successfully built geojsonio
# Installing collected packages: cryptography, jwcrypto, github3.py, geojsonio
# Successfully installed cryptography-2.9.2 geojsonio-0.0.3 github3.py-1.3.0 jwcrypto-0.7

# %%
# Import the geojsonio python module
# You may need to install this on your system first
import geojsonio

# Assign the url variable to display the geojsonio map
url = geojsonio.display(res.text)

# %%
# Assign the next_url variable to the next page of results from the response (Setup the next page of results)
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %%
# Setup the next page of results
next_url = geojson["_links"]["_next"]

# Get the next page of results
res = session.get(next_url)

# Assign the response to a variable
geojson = res.json()

# Get the url see results on geojson.io
url = geojsonio.to_geojsonio(res.text)

# %%
# Assign a variable to the search result features (items)
features = geojson["features"]

# Get the first result's feature
feature = features[0]

# Print the ID
p(feature["id"])

# Print the permissions
p(feature["_permissions"])
# Out:
# "20200504_185139_1004"
# [
#   "assets.analytic:download",
#   "assets.analytic_dn:download",
#   "assets.analytic_xml:download",
#   "assets.analytic_dn_xml:download",
#   "assets.basic_analytic:download",
#   "assets.basic_analytic_dn:download",
#   "assets.basic_analytic_dn_xml:download",
#   "assets.basic_analytic_dn_rpc:download",
#   "assets.basic_analytic_xml:download",
#   "assets.basic_analytic_rpc:download",
#   "assets.basic_udm:download",
#   "assets.udm:download",
#   "assets.visual:download",
#   "assets.visual_xml:download"
# ]

# %%
# Get the assets link for the item
assets_url = feature["_links"]["assets"]

# Print the assets link
print(assets_url)
# Out:
# https://api.planet.com/data/v1/item-types/PSScene3Band/items/20200504_185139_1004/assets/

# %%
# Send a GET request to the assets url for the item (Get the list of available assets for the item)
res = session.get(assets_url)

# Assign a variable to the response
assets = res.json()

# %%
# Print the asset types that are available
print(assets.keys())
# Out:
# dict_keys(['analytic', 'analytic_dn', 'analytic_dn_xml', 'analytic_xml', 'basic_analytic', 'basic_analytic_dn', 'basic_analytic_dn_rpc', 'basic_analytic_dn_xml', 'basic_analytic_rpc', 'basic_analytic_xml', 'basic_udm', 'udm', 'visual', 'visual_xml'])

# %%
# Assign a variable to the visual asset from the item's assets
visual = assets["visual"]

# Print the visual asset data
p(visual)
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjAwNTA0XzE4NTEzOV8xMDA0IiwgImMiOiAiUFNTY2VuZTNCYW5kIiwgInQiOiAidmlzdWFsIiwgImN0IjogIml0ZW0tdHlwZSJ9",
#     "activate": "https://api.planet.com/data/v1/assets/eyJpIjogIjIwMjAwNTA0XzE4NTEzOV8xMDA0IiwgImMiOiAiUFNTY2VuZTNCYW5kIiwgInQiOiAidmlzdWFsIiwgImN0IjogIml0ZW0tdHlwZSJ9/activate",
#     "type": "https://api.planet.com/data/v1/asset-types/visual"
#   },
#   "_permissions": [
#     "download"
#   ],
#   "md5_digest": null,
#   "status": "inactive",
#   "type": "visual"
# }

# %%
# Setup the activation url for a particular asset (in this case the visual asset)
activation_url = visual["_links"]["activate"]

# Send a request to the activation url to activate the item
res = session.get(activation_url)

# Print the response from the activation request
p(res.status_code)
# Out:
# 403

# %%
import time

asset_activated = False

while asset_activated == False:
    # Send a request to the item's assets url
    res = session.get(assets_url)

    # Assign a variable to the item's assets url response
    assets = res.json()

    # Assign a variable to the visual asset from the response
    visual = assets["visual"]

    asset_status = visual["status"]
    
    # If asset is already active, we are done
    if asset_status == 'active':
        asset_activated = True
        print("Asset is active and ready to download")

# Print the visual asset data    
p(visual)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-46-0e1a77cc16a7> in <module>()
#       8
#       9     # Assign a variable to the item's assets url response
# ---> 10     assets = res.json()
#      11
#      12     # Assign a variable to the visual asset from the response
#
# /usr/local/lib/python3.6/dist-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /usr/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
